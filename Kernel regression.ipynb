# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.nonparametric.kernel_regression import KernelReg
from scipy.signal import argrelextrema
de = pd.read_csv("/Users/riomoukiri/Desktop/CHUPROJECT/defi_data_1.csv")
for i in range(1005):
    de_29 = de.loc[i:i+29,['kyberret','Date']]
    de_29 = de_29.reset_index(drop =  True)
    de_29 = de_29.reset_index()
    kr = KernelReg(de_29["kyberret"],de_29['index'], var_type = 'c', bw='cv_ls', ckertype='gaussian', defaults=None)
    f = kr.fit(de_29['index'])
    f = pd.DataFrame(f).T
    de_29 = de_29.join(f)
    a = i 
    b = a+29
    c = str(a)+'_'+str(b)
    de_29.to_csv('/Users/riomoukiri/Desktop/CHUPROJECT/kyber/'+c+'.csv')    
for i in range(1005):
    de_29 = de.loc[i:i+29,['linkret','Date']]
    de_29 = de_29.reset_index(drop =  True)
    de_29 = de_29.reset_index()
    kr = KernelReg(de_29["linkret"],de_29['index'], var_type = 'c', bw='cv_ls', ckertype='gaussian', defaults=None)
    f = kr.fit(de_29['index'])
    f = pd.DataFrame(f).T
    de_29 = de_29.join(f)
    a = i 
    b = a+29
    c = str(a)+'_'+str(b)
    de_29.to_csv('/Users/riomoukiri/Desktop/CHUPROJECT/link/'+c+'.csv')   
for i in range(1005):
    de_29 = de.loc[i:i+29,['aaveret','Date']]
    de_29 = de_29.reset_index(drop =  True)
    de_29 = de_29.reset_index()
    kr = KernelReg(de_29["aaveret"],de_29['index'], var_type = 'c', bw='cv_ls', ckertype='gaussian', defaults=None)
    f = kr.fit(de_29['index'])
    f = pd.DataFrame(f).T
    de_29 = de_29.join(f)
    a = i 
    b = a+29
    c = str(a)+'_'+str(b)
    de_29.to_csv('/Users/riomoukiri/Desktop/CHUPROJECT/aave/'+c+'.csv')    
for i in range(1005):
    de_29 = de.loc[i:i+29,['makerret','Date']]
    de_29 = de_29.reset_index(drop =  True)
    de_29 = de_29.reset_index()
    kr = KernelReg(de_29["makerret"],de_29['index'], var_type = 'c', bw='cv_ls', ckertype='gaussian', defaults=None)
    f = kr.fit(de_29['index'])
    f = pd.DataFrame(f).T
    de_29 = de_29.join(f)
    a = i 
    b = a+29
    c = str(a)+'_'+str(b)
    de_29.to_csv('/Users/riomoukiri/Desktop/CHUPROJECT/maker/'+c+'.csv')
for i in range(1005):
    de_29 = de.loc[i:i+29,['zeroret','Date']]
    de_29 = de_29.reset_index(drop =  True)
    de_29 = de_29.reset_index()
    kr = KernelReg(de_29["zeroret"],de_29['index'], var_type = 'c', bw='cv_ls', ckertype='gaussian', defaults=None)
    f = kr.fit(de_29['index'])
    f = pd.DataFrame(f).T
    de_29 = de_29.join(f)
    a = i 
    b = a+29
    c = str(a)+'_'+str(b)
    de_29.to_csv('/Users/riomoukiri/Desktop/CHUPROJECT/zero/'+c+'.csv')
